# %%
import pandas as pd
import numpy as np

# %%
w1=pd.read_csv("weather1.csv")
w1.head()
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017         32.0        6.0   Rain
# 1  1/4/2017          NaN        9.0  Sunny
# 2  1/5/2017         28.0        NaN   Snow
# 3  1/6/2017          NaN        7.0    NaN
# 4  1/7/2017         32.0        NaN   Rain

# %%
w1.isnull().sum()
# Out:
# day            0
# temperature    4
# windspeed      4
# event          2
# dtype: int64

# %% [markdown]
# # method=bfill :- is used for the fill the null by its before value

# %%
new_df=w1.fillna(method='bfill')
new_df
# Out:
#          day  temperature  windspeed   event
# 0   1/1/2017         32.0        6.0    Rain
# 1   1/4/2017         28.0        9.0   Sunny
# 2   1/5/2017         28.0        7.0    Snow
# 3   1/6/2017         32.0        7.0    Rain
# 4   1/7/2017         32.0        8.0    Rain
# 5   1/8/2017         34.0        8.0   Sunny
# 6   1/9/2017         34.0        8.0  Cloudy
# 7  1/10/2017         34.0        8.0  Cloudy
# 8  1/11/2017         40.0       12.0   Sunny

# %% [markdown]
# # method=ffill :- is used to fill the null value by its after value

# %%
new_df=w1.fillna(method='ffill')
new_df
# Out:
#          day  temperature  windspeed   event
# 0   1/1/2017         32.0        6.0    Rain
# 1   1/4/2017         32.0        9.0   Sunny
# 2   1/5/2017         28.0        9.0    Snow
# 3   1/6/2017         28.0        7.0    Snow
# 4   1/7/2017         32.0        7.0    Rain
# 5   1/8/2017         32.0        7.0   Sunny
# 6   1/9/2017         32.0        7.0   Sunny
# 7  1/10/2017         34.0        8.0  Cloudy
# 8  1/11/2017         40.0       12.0   Sunny

# %% [markdown]
# # DataFrame :- rectangular data(like a speadsheet)is the basic data structure for statistical and machine learning models.
#
# ## feature:- A column within a table is commanly refferred to as a feature
# ## synonms:- Attributes, input, variable
# # Records:- A Row within a table is commanly refferred to as a record
# ## synonms:- dependent variable, reponse terget, output

# %%
tp=pd.read_csv("tips.csv")
tp.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    object
#  3   smoker      244 non-null    object
#  4   day         244 non-null    object
#  5   time        244 non-null    object
#  6   size        244 non-null    int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 13.5+ KB

# %%
tp.isnull().any()
# Out:
# total_bill    False
# tip           False
# sex           False
# smoker        False
# day           False
# time          False
# size          False
# dtype: bool

# %%
tp.isnull().sum()
# Out:
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %% [markdown]
# # value_counts() :- is used to check the number of each element in records

# %%
tp['sex'].value_counts()
# Out:
# Male      157
# Female     87
# Name: sex, dtype: int64

# %%
tp['smoker'].value_counts()
# Out:
# No     151
# Yes     93
# Name: smoker, dtype: int64

# %%
tp['day'].value_counts()
# Out:
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: day, dtype: int64

# %%
tp['size'].value_counts()
# Out:
# 2    156
# 3     38
# 4     37
# 5      5
# 1      4
# 6      4
# Name: size, dtype: int64

# %%
import seaborn as sns
## relational plotting :-
sns.set(style='darkgrid')

# %%
#scatter plotting or line.
# by default it always scatter plot
sns.relplot(data=tp,x='total_bill',y='tip')

# %% [markdown]
# # keyterms for estimated of values
# ## 1) Mean value, 2) weighted mean value
# ## 3) medium value 4)percentile 5)weighted medium value
# ##

# %%
tp.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %% [markdown]
# # Relplot (relational)

# %% [markdown]
# ## It has four types of style: 1) whitegrid 2)darkgrid 3)white 4)dark 5)ticks

# %%
sns.set(style='darkgrid')

# %% [markdown]
# # It has two types - scatter plotting and line plotting. By default it is always scatter plotting

# %% [markdown]
# # Scatter Plotting

# %%
sns.relplot(data=tp,x='total_bill',y='tip')

# %% [markdown]
# # <font color="red">Line Plotting

# %% [markdown]
# ### For getting line plot used kind
# ### kind is used for changing the pattern of visulization

# %%
sns.relplot(data=tp,x='total_bill',y='tip',kind='line')

# %%
sns.lineplot(data=tp,x='total_bill',y='tip')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# # hue :- is a parameter for design in seaborn

# %%
sns.relplot(data=tp,x="total_bill",y="tip",hue="sex")

# %% [markdown]
# # palette :- is used to set colors for points(default is orange and blue)

# %%
color=['Red','yellow']
sns.relplot(data=tp,x='total_bill',y='tip',hue='sex',palette=color)

# %% [markdown]
# # style parameter is used for diplaying the value in diffrent style

# %%
sns.relplot(data=tp,x='total_bill',y='tip',hue='sex',style='smoker')

# %%
sns.relplot(data=tp,x='total_bill',y='tip',hue='sex',style='time')

# %%
sns.relplot(data=tp,x='total_bill',y='tip',hue='sex',style='time',size='size')

# %%
sns.relplot(data=tp,x='total_bill',y='tip',hue='sex',style='time',size='size',sizes=(15,200))

# %% [markdown]
# ## seprating the smoker and non-smoker by row and column

# %%
#seprating the smoker and non-smoker by row and column
sns.relplot(data=tp,x='total_bill',y='tip',hue='sex',row='sex',col='smoker')

# %%
sns.relplot(data=tp,x='total_bill',y='tip',hue='sex',row='sex',col='day')

# %%
np.random.seed(0)
df1=pd.DataFrame(dict(time=np.arange(500), value=np.random.randn(500).cumsum()))
df1.head()
# Out:
#    time     value
# 0     0  1.764052
# 1     1  2.164210
# 2     2  3.142948
# 3     3  5.383841
# 4     4  7.251399

# %%
sns.relplot(x='time',y='value',data=df1,kind='line')

# %%
help(np.cumsum)
# Out:
# Help on function cumsum in module numpy:
#
# cumsum(a, axis=None, dtype=None, out=None)
#     Return the cumulative sum of the elements along a given axis.
#
#     Parameters
#     ----------
#     a : array_like
#         Input array.
#     axis : int, optional
#         Axis along which the cumulative sum is computed. The default
#         (None) is to compute the cumsum over the flattened array.
#     dtype : dtype, optional
#         Type of the returned array and of the accumulator in which the
#         elements are summed.  If `dtype` is not specified, it defaults
#         to the dtype of `a`, unless `a` has an integer dtype with a
#         precision less than that of the default platform integer.  In
#         that case, the default platform integer is used.
#     out : ndarray, optional
#         Alternative output array in which to place the result. It must
#         have the same shape and buffer length as the expected output
# ...

# %%
df2=pd.DataFrame(np.random.randn(500,2).cumsum(axis=0),
                columns=['time','value'])
df2.head()
# Out:
#        time     value
# 0 -0.002965 -1.777044
# 1  0.126528 -3.860278
# 2 -0.555217 -4.471344
# 3 -1.264067 -3.019816
# 4 -0.728557 -3.419385

# %%
sns.relplot(x='time',y='value',data=df2,kind='line')

# %%
sns.relplot(x='time',y='value',data=df2,kind='line',sort=False) # default value of sort is True

# %%
import seaborn as sns
fm=sns.load_dataset('fmri')
fm.head()
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File C:\ProgramData\anaconda3\lib\urllib\request.py:1348, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1347 try:
# -> 1348     h.request(req.get_method(), req.selector, req.data, headers,
#    1349               encode_chunked=req.has_header('Transfer-encoding'))
#    1350 except OSError as err: # timeout error
#
# File C:\ProgramData\anaconda3\lib\http\client.py:1282, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1281 """Send a complete request to the server."""
# -> 1282 self._send_request(method, url, body, headers, encode_chunked)
#
# File C:\ProgramData\anaconda3\lib\http\client.py:1328, in HTTPConnection._send_request(self, method, url, body, headers, encode_chunked)
#    1327     body = _encode(body, 'body')
# ...

# %%
sns.relplot(data=fm,x='timepoint',y='signal',kind='line')

# %%
sns.relplot(data=fm,x='timepoint',y='signal',kind='line',ci=None)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[56], line 1
# ----> 1 sns.relplot(data=fm,x='timepoint',y='signal',kind='line',ci=None)
#
# NameError: name 'fm' is not defined

# %%
sns.relplot(data=fm,x='timepoint',y='signal',kind='line',ci='st')

# %%
sns.relplot(data=fm,x='timepoint',y='signal',kind='line',hue='event')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[61], line 1
# ----> 1 sns.relplot(data=fm,x='timepoint',y='signal',kind='line',hue='event')
#
# NameError: name 'fm' is not defined

# %%
sns.relplot(data=fm,x='timepoint',y='signal',kind='line',hue='event',style='region')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[65], line 1
# ----> 1 sns.relplot(data=fm,x='timepoint',y='signal',kind='line',hue='event',style='region')
#
# NameError: name 'fm' is not defined

# %%
flight=sns.load_dataset('flights')
flight.head()
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File C:\ProgramData\anaconda3\lib\urllib\request.py:1348, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1347 try:
# -> 1348     h.request(req.get_method(), req.selector, req.data, headers,
#    1349               encode_chunked=req.has_header('Transfer-encoding'))
#    1350 except OSError as err: # timeout error
#
# File C:\ProgramData\anaconda3\lib\http\client.py:1282, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1281 """Send a complete request to the server."""
# -> 1282 self._send_request(method, url, body, headers, encode_chunked)
#
# File C:\ProgramData\anaconda3\lib\http\client.py:1328, in HTTPConnection._send_request(self, method, url, body, headers, encode_chunked)
#    1327     body = _encode(body, 'body')
# ...

# %%
sns.relplot(data=fm,x='year',y='passenger',kind='line',hue='month')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[71], line 1
# ----> 1 sns.relplot(data=fm,x='year',y='passenger',kind='line',hue='month',marker=True)
#
# NameError: name 'fm' is not defined

# %%
sns.relplot(data=fm,x='year',y='passenger',kind='line',hue='month',marketr=True)
#
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[72], line 1
# ----> 1 sns.relplot(data=fm,x='year',y='passenger',kind='line',hue='month',marketr=True)
#
# NameError: name 'fm' is not defined

# %% [markdown]
# # Categorial plotting
# ## 2 types of categorial plotting :- 1) catplot 2)stripplot
# ## by default catplot

# %%
sns.catplot(data=tp,x='day',y='tip')

# %%
sns.catplot(data=tp,x='day',y='tip',jitter=False)

# %%
import matplotlib.pyplot as plt
sns.catplot(data=tp,x='day',y='tip',jitter=False)
plt.show() # to remove message

# %% [markdown]
# # swarm plotting

# %%
sns.catplot(data=tp,x='day',y='tip',kind='swarm')
# Out:
# C:\ProgramData\anaconda3\lib\site-packages\seaborn\categorical.py:3544: UserWarning: 8.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.catplot(data=tp,x='day',y='tip',kind='swarm',hue='size')
# Out:
# C:\ProgramData\anaconda3\lib\site-packages\seaborn\categorical.py:3544: UserWarning: 8.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
tp.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# # order[] :- this attribute is used for define order of plot on x axis.

# %%
sns.catplot(data=tp,x='smoker',y='tip',order=['No','Yes'])

# %%
tp['sex'].value_counts()
# Out:
# Male      157
# Female     87
# Name: sex, dtype: int64

# %%
sns.countplot(x='sex',data=tp)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.countplot(x='sex',data=tp,order=['Male','Female'])
# set order as 1 bar is male and second is female
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.countplot(x='day',data=tp)
# Out:
# <Axes: xlabel='day', ylabel='count'>

# %%
tp.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %% [markdown]
# # kind='box' :- is used to represent data into box bar

# %%
sns.catplot(x='day',y='tip',data=tp,kind='box')

# %%
sns.catplot(x='day',y='tip',data=tp,kind='violin')

# %%
tp['day'].describe()
# Out:
# count     244
# unique      4
# top       Sat
# freq       87
# Name: day, dtype: object

# %% [markdown]
# # thur :- is storing only thursday data from tp

# %%
thur=tp[tp['day']=='Thur']
thur.head()
# Out:
#     total_bill   tip   sex smoker   day   time  size
# 77       27.20  4.00  Male     No  Thur  Lunch     4
# 78       22.76  3.00  Male     No  Thur  Lunch     2
# 79       17.29  2.71  Male     No  Thur  Lunch     2
# 80       19.44  3.00  Male    Yes  Thur  Lunch     2
# 81       16.66  3.40  Male     No  Thur  Lunch     2

# %%
thur.describe()
# Out:
#        total_bill        tip       size
# count   62.000000  62.000000  62.000000
# mean    17.682742   2.771452   2.451613
# std      7.886170   1.240223   1.066285
# min      7.510000   1.250000   1.000000
# 25%     12.442500   2.000000   2.000000
# 50%     16.200000   2.305000   2.000000
# 75%     20.155000   3.362500   2.000000
# max     43.110000   6.700000   6.000000

# %%
sns.catplot(x='day',y='tip',data=thur,kind='box')

# %%
sns.catplot(x='day',y='tip',data=thur,kind='violin')

# %% [markdown]
# # inner='stick' :- this attribute is used for

# %%
sns.catplot(x='day',y='tip',data=thur,kind='violin',inner='stick')

# %%
sns.catplot(x='day',y='tip',data=thur,kind='box',hue='sex')

# %% [markdown]
# # dodge=False :- it is used to marge to boxes

# %%
sns.catplot(x='day',y='tip',data=thur,kind='box',hue='sex', dodge=False)

# %% [markdown]
# # kind='bar' :- it used to represent x axis in bars

# %%
sns.catplot(x='sex',y='tip',data=tp,kind='bar')

# %%
sns.displot(data=tp,x='total_bill',y='tip')

# %%
import seaborn as sns
sns.distplot(tp.tip,rug=True)
